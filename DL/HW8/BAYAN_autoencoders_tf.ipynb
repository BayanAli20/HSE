# %% [markdown]
# ### Denoising Autoencoders And Where To Find Them (10 pts)
#
# Today we're going to train deep autoencoders and deploy them to faces and search for similar images.
#
# Our new test subjects are human faces from the [lfw dataset](http://vis-www.cs.umass.edu/lfw/).

# %%
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py -O lfw_dataset.py
# Out:
# --2021-11-24 22:03:57--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/hw3_19/homework03/lfw_dataset.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2734 (2.7K) [text/plain]
# Saving to: ‘lfw_dataset.py’
#
# lfw_dataset.py      100%[===================>]   2.67K  --.-KB/s    in 0s
#
# 2021-11-24 22:03:57 (47.7 MB/s) - ‘lfw_dataset.py’ saved [2734/2734]

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 1.5 MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# jax 0.2.25 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.1.0

# %%
import numpy as np
from lfw_dataset import fetch_lfw_dataset
from sklearn.model_selection import train_test_split
X, attr = fetch_lfw_dataset(use_raw=True,dimx=32,dimy=32)
X = X.astype('float32') / 256.0

img_shape = X.shape[1:]

X_train, X_test = train_test_split(X, test_size=0.1,random_state=42)
# Out:
# images not found, donwloading...
# extracting...
# done
# attributes not found, downloading...
# done

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.title('sample image')
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X[i])

print("X shape:",X.shape)
print("attr shape:",attr.shape)
# Out:
# X shape: (13143, 32, 32, 3)
# attr shape: (13143, 73)

# %% [markdown]
# ### Autoencoder architecture
#
# Let's design autoencoder as two sequential keras models: the encoder and decoder respectively.
#
# We will then use symbolic API to apply and train those models.
#
# <img src="http://nghiaho.com/wp-content/uploads/2012/12/autoencoder_network1.png" width=640px>

# %%
import tensorflow as tf
import keras, keras.layers as L
s = keras.backend.get_session()

# %% [markdown]
# ## First step: PCA
#
# Principial Component Analysis is a popular dimensionality reduction method.
#
# Under the hood, PCA attempts to decompose object-feature matrix $X$ into two smaller matrices: $W$ and $\hat W$ minimizing _mean squared error_:
#
# $$\|(X W) \hat{W} - X\|^2_2 \to_{W, \hat{W}} \min$$
# - $X \in \mathbb{R}^{n \times m}$ - object matrix (**centered**);
# - $W \in \mathbb{R}^{m \times d}$ - matrix of direct transformation;
# - $\hat{W} \in \mathbb{R}^{d \times m}$ - matrix of reverse transformation;
# - $n$ samples, $m$ original dimensions and $d$ target dimensions;
#
# In geometric terms, we want to find d axes along which most of variance occurs. The "natural" axes, if you wish.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/9/90/PCA_fish.png/256px-PCA_fish.png)
#
#
# PCA can also be seen as a special case of an autoencoder.
#
# * __Encoder__: X -> Dense(d units) -> code
# * __Decoder__: code -> Dense(m units) -> X
#
# Where Dense is a fully-connected layer with linear activaton:   $f(X) = W \cdot X + \vec b $
#
#
# Note: the bias term in those layers is responsible for "centering" the matrix i.e. substracting mean.

# %%
def build_pca_autoencoder(img_shape,code_size=32):
    """
    Here we define a simple linear autoencoder as described above.
    We also flatten and un-flatten data to be compatible with image shapes
    """
    
    encoder = keras.models.Sequential()
    encoder.add(L.InputLayer(img_shape))
    encoder.add(L.Flatten())                  #flatten image to vector
    encoder.add(L.Dense(code_size))           #actual encoder

    decoder = keras.models.Sequential()
    decoder.add(L.InputLayer((code_size,)))
    decoder.add(L.Dense(np.prod(img_shape)))  #actual decoder, height*width*3 units
    decoder.add(L.Reshape(img_shape))         #un-flatten
    
    return encoder,decoder

# %% [markdown]
# Meld them together into one model

# %%
encoder,decoder = build_pca_autoencoder(img_shape,code_size=32)

inp = L.Input(img_shape)
code = encoder(inp)
reconstruction = decoder(code)

autoencoder = keras.models.Model(inp,reconstruction)
autoencoder.compile('adamax','mse')

# %%
autoencoder.fit(x=X_train,y=X_train,epochs=32,
                validation_data=[X_test,X_test])
# Out:
# Epoch 1/32
# 370/370 [==============================] - 3s 3ms/step - loss: 0.0292 - val_loss: 0.0177
# Epoch 2/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0148 - val_loss: 0.0132
# Epoch 3/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 4/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0099 - val_loss: 0.0093
# Epoch 5/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 6/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 7/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 8/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 9/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 10/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 11/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 12/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 13/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 14/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 15/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 16/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 17/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 18/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 19/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 20/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 21/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 22/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 23/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 24/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 25/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 26/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 27/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 28/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 29/32
# 370/370 [==============================] - 1s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 30/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 31/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 32/32
# 370/370 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0051

# %%
def visualize(img,encoder,decoder):
    """Draws original, encoded and decoded images"""
    code = encoder.predict(img[None])[0]
    reco = decoder.predict(code[None])[0]

    plt.subplot(1,3,1)
    plt.title("Original")
    plt.imshow(img)

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.reshape([code.shape[-1]//2,-1]))

    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    plt.imshow(reco.clip(0,1))
    plt.show()

# %%
score = autoencoder.evaluate(X_test,X_test,verbose=0)
print("Final MSE:",score)

for i in range(5):
    img = X_test[i]
    visualize(img,encoder,decoder)
# Out:
# Final MSE: 0.005100019741803408

# %% [markdown]
# ### Going deeper
#
# PCA is neat but surely we can do better. This time we want you to build a deep autoencoder by... stacking more layers.
#
# In particular, your encoder and decoder should be at least 3 layers deep each. You can use any nonlinearity you want and any number of hidden units in non-bottleneck layers provided you can actually afford training it.
#
# ![layers](https://pbs.twimg.com/media/CYggEo-VAAACg_n.png:small)
#
# A few sanity checks:
# * There shouldn't be any hidden layer smaller than bottleneck (encoder output).
# * Don't forget to insert nonlinearities between intermediate dense layers.
# * Convolutional layers are allowed but not required. To undo convolution use L.Deconv2D, pooling - L.UpSampling2D.
# * Adding activation after bottleneck is allowed, but not strictly necessary.

# %%
def build_deep_autoencoder(img_shape,code_size):
    H,W,C = img_shape
    
    encoder = keras.models.Sequential()
    encoder.add(L.InputLayer(img_shape))
    encoder.add(L.Conv2D(38, (3, 3), padding="same",strides=1, activation='elu'))
    encoder.add(L.MaxPooling2D((2, 2)))
    encoder.add(L.Conv2D(64, (3, 3),  padding="same", strides=1,activation='elu'))
    encoder.add(L.MaxPooling2D((2, 2)))
    encoder.add(L.Conv2D(128, (3, 3),padding="same",strides=1, activation='elu'))
    encoder.add(L.MaxPooling2D((2, 2)))
    encoder.add(L.Conv2D(256, (3, 3), padding="same",strides=1, activation='elu'))
    encoder.add(L.MaxPooling2D((2, 2)))  
    encoder.add(L.Flatten()) 
    encoder.add(L.Dense(1024))                 
    encoder.add(L.Dense(code_size))


    decoder = keras.models.Sequential()
    decoder.add(L.InputLayer((code_size,)))
    decoder.add(L.Dense(1024))               
    decoder.add(L.Reshape((2,2,256)))
    decoder.add(L.Conv2DTranspose(filters=128, kernel_size=(3, 3), strides=2, activation='elu', padding='same'))
    decoder.add(L.Conv2DTranspose(filters=64, kernel_size=(3, 3), strides=2, activation='elu', padding='same'))
    decoder.add(L.Conv2DTranspose(filters=38, kernel_size=(3, 3), strides=2, activation='elu', padding='same'))
    decoder.add(L.Conv2DTranspose(filters=3, kernel_size=(3, 3), strides=2,activation=None, padding='same'))



    #<Your code: define encoder as per instructions above>
    
    return encoder,decoder

# %%
#Check autoencoder shapes along different code_sizes
get_dim = lambda layer: np.prod(layer.output_shape[1:])
for code_size in [1,8,32,128,512,1024]:
    encoder,decoder = build_deep_autoencoder(img_shape,code_size=code_size)
    print("Testing code size %i" % code_size)
    assert encoder.output_shape[1:]==(code_size,),"encoder must output a code of required size"
    assert decoder.output_shape[1:]==img_shape,   "decoder must output an image of valid shape"
    assert len(encoder.trainable_weights)>=6,     "encoder must contain at least 3 dense layers"
    assert len(decoder.trainable_weights)>=6,     "decoder must contain at least 3 dense layers"
    
    for layer in encoder.layers + decoder.layers:
        assert get_dim(layer) >= code_size, "Encoder layer %s is smaller than bottleneck (%i units)"%(layer.name,get_dim(layer))

print("All tests passed!")
# Out:
# Testing code size 1
# Testing code size 8
# Testing code size 32
# Testing code size 128
# Testing code size 512
# Testing code size 1024
# All tests passed!

# %% [markdown]
# __Hint:__ if you're getting "Encoder layer is smaller than bottleneck" error, use code_size when defining intermediate layers.
#
# For example, such layer may have code_size*2 units.

# %%
encoder,decoder = build_deep_autoencoder(img_shape,code_size=32)

inp = L.Input(img_shape)
code = encoder(inp)
reconstruction = decoder(code)

autoencoder = keras.models.Model(inp,reconstruction)
autoencoder.compile('adamax','mse')

# %%
encoder.summary()
decoder.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 32, 32, 38)        1064
#
#  max_pooling2d_54 (MaxPoolin  (None, 16, 16, 38)       0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 16, 16, 64)        21952
#
#  max_pooling2d_55 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_56 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 4, 4, 256)         295168
#
#  max_pooling2d_57 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  flatten_22 (Flatten)        (None, 1024)              0
#
#  dense_65 (Dense)            (None, 1024)              1049600
#
#  dense_66 (Dense)            (None, 32)                32800
#
# =================================================================
# Total params: 1,474,440
# Trainable params: 1,474,440
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_67 (Dense)            (None, 1024)              33792
#
#  reshape_22 (Reshape)        (None, 2, 2, 256)         0
#
#  conv2d_transpose_84 (Conv2D  (None, 4, 4, 128)        295040
#  Transpose)
#
#  conv2d_transpose_85 (Conv2D  (None, 8, 8, 64)         73792
#  Transpose)
#
#  conv2d_transpose_86 (Conv2D  (None, 16, 16, 38)       21926
#  Transpose)
#
#  conv2d_transpose_87 (Conv2D  (None, 32, 32, 3)        1029
#  Transpose)
#
# =================================================================
# Total params: 425,579
# Trainable params: 425,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training may take some 20 minutes.

# %%
autoencoder.fit(x=X_train,y=X_train,epochs=32,
                validation_data=[X_test,X_test])
# Out:
# Epoch 1/32
# 370/370 [==============================] - 4s 8ms/step - loss: 0.0228 - val_loss: 0.0126
# Epoch 2/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0108 - val_loss: 0.0098
# Epoch 3/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 4/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 5/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 6/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 7/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 8/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 9/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 10/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 11/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 12/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 13/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 14/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 15/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 16/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 17/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 18/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 19/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 20/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 21/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 22/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 23/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 24/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 25/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 26/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 27/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0044 - val_loss: 0.0046
# Epoch 28/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0044 - val_loss: 0.0046
# Epoch 29/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 30/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 31/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 32/32
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0042 - val_loss: 0.0044

# %%
reconstruction_mse = autoencoder.evaluate(X_test,X_test,verbose=0)
assert reconstruction_mse <= 0.005, "Compression is too lossy. See tips below."
assert len(encoder.output_shape)==2 and encoder.output_shape[1]==32, "Make sure encoder has code_size units"
print("Final MSE:", reconstruction_mse)
for i in range(5):
    img = X_test[i]
    visualize(img,encoder,decoder)
# Out:
# Final MSE: 0.004428688902407885

# %% [markdown]
# __Tips:__ If you keep getting "Compression to lossy" error, there's a few things you might try:
#
# * Make sure it converged. Some architectures need way more than 32 epochs to converge. They may fluctuate a lot, but eventually they're going to get good enough to pass. You may train your network for as long as you want.
#
# * Complexity. If you already have, like, 152 layers and still not passing threshold, you may wish to start from something simpler instead and go in small incremental steps.
#
# * Architecture. You can use any combination of layers (including convolutions, normalization, etc) as long as __encoder output only stores 32 numbers per training object__.
#
# A cunning learner can circumvent this last limitation by using some manual encoding strategy, but he is strongly recommended to avoid that.

# %% [markdown]
# ## Denoising AutoEncoder
#
# Let's now make our model into a denoising autoencoder.
#
# We'll keep your model architecture, but change the way it trains. In particular, we'll corrupt it's input data randomly before each epoch.
#
# There are many strategies to apply noise. We'll implement two popular one: adding gaussian noise and using dropout.

# %%
def apply_gaussian_noise(X,sigma=0.1):
    """
    adds noise from normal distribution with standard deviation sigma
    :param X: image tensor of shape [batch,height,width,3]
    """
    
    noise = np.random.normal(loc=0, scale=sigma, size=X.shape)
        
    return X + noise

# %%
#noise tests
theoretical_std = (X[:100].std()**2 + 0.5**2)**.5
our_std = apply_gaussian_noise(X[:100],sigma=0.5).std()
assert abs(theoretical_std - our_std) < 0.01, "Standard deviation does not match it's required value. Make sure you use sigma as std."
assert abs(apply_gaussian_noise(X[:100],sigma=0.5).mean() - X[:100].mean()) < 0.01, "Mean has changed. Please add zero-mean noise"

# %%
plt.subplot(1,4,1)
plt.imshow(X[0])
plt.subplot(1,4,2)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.01)[0])
plt.subplot(1,4,3)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.1)[0])
plt.subplot(1,4,4)
plt.imshow(apply_gaussian_noise(X[:1],sigma=0.5)[0])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
encoder,decoder = build_deep_autoencoder(img_shape,code_size=512)
assert encoder.output_shape[1:]==(512,), "encoder must output a code of required size"

inp = L.Input(img_shape)
code = encoder(inp)
reconstruction = decoder(code)

autoencoder = keras.models.Model(inp,reconstruction)
autoencoder.compile('adamax','mse')

# %%
for i in range(50):
    print("Epoch %i/50, Generating corrupted samples..."%i)
    X_train_noise = apply_gaussian_noise(X_train)
    X_test_noise = apply_gaussian_noise(X_test)
    
    autoencoder.fit(x=X_train_noise,y=X_train,epochs=1,
                    validation_data=[X_test_noise,X_test])
# Out:
# Epoch 0/50, Generating corrupted samples...
# 370/370 [==============================] - 4s 8ms/step - loss: 0.0194 - val_loss: 0.0108
# Epoch 1/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0092 - val_loss: 0.0078
# Epoch 2/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 3/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 4/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 5/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 6/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 7/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 8/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 9/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 10/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 11/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 12/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 13/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 14/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 15/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 16/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 17/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 18/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 19/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 20/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 21/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 22/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 23/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 24/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 25/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 26/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 27/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 28/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 29/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 30/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 31/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 32/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 33/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 34/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 35/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 36/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 37/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 38/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 39/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 40/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 41/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 42/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 8ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 43/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 44/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 45/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 46/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 47/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 48/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 49/50, Generating corrupted samples...
# 370/370 [==============================] - 3s 7ms/step - loss: 0.0018 - val_loss: 0.0020

# %% [markdown]
# __Note:__ if it hasn't yet converged, increase the number of iterations.
#
# __Bonus:__ replace gaussian noise with masking random rectangles on image.

# %%
denoising_mse = autoencoder.evaluate(apply_gaussian_noise(X_test),X_test,verbose=0)
print("Final MSE:", denoising_mse)
for i in range(5):
    img = X_test[i]
    visualize(img,encoder,decoder)
# Out:
# Final MSE: 0.001979054417461157

# %%
encoder.save("./encoder.h5")
decoder.save("./decoder.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Image retrieval with autoencoders
#
# So we've just trained a network that converts image into itself imperfectly. This task is not that useful in and of itself, but it has a number of awesome side-effects. Let's see it in action.
#
# First thing we can do is image retrieval aka image search. We we give it an image and find similar images in latent space.
#
# To speed up retrieval process, we shall use Locality-Sensitive Hashing on top of encoded vectors. We'll use scikit-learn's implementation for simplicity. In practical scenario, you may want to use [specialized libraries](https://erikbern.com/2015/07/04/benchmark-of-approximate-nearest-neighbor-libraries.html) for better performance and customization.

# %%
images = X_train
codes = encoder.predict(images)
assert len(codes) == len(images)

# %%
from sklearn.neighbors import LSHForest
lshf = LSHForest(n_estimators=50).fit(codes)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-40-a150949e6beb> in <module>()
# ----> 1 from sklearn.neighbors import LSHForest
#       2 lshf = LSHForest(n_estimators=50).fit(codes)
#
# ImportError: cannot import name 'LSHForest' from 'sklearn.neighbors' (/usr/local/lib/python3.7/dist-packages/sklearn/neighbors/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# I could not fix the error above (((

# %%
def get_similar(image, n_neighbors=5):
    assert image.ndim==3,"image must be [batch,height,width,3]"

    code = encoder.predict(image[None])
    
    (distances,),(idx,) = lshf.kneighbors(code,n_neighbors=n_neighbors)
    
    return distances,images[idx]

# %%
def show_similar(image):
    
    distances,neighbors = get_similar(image,n_neighbors=11)
    
    plt.figure(figsize=[8,6])
    plt.subplot(3,4,1)
    plt.imshow(image)
    plt.title("Original image")
    
    for i in range(11):
        plt.subplot(3,4,i+2)
        plt.imshow(neighbors[i])
        plt.title("Dist=%.3f"%distances[i])
    plt.show()

# %%
#smiles
show_similar(X_test[2])

# %%
#ethnicity
show_similar(X_test[500])

# %%
#glasses
show_similar(X_test[66])

# %% [markdown]
# ## Bonus: cheap image morphing

# %%
s = tf.keras.backend.clear_session()
encoder, decoder = build_deep_autoencoder(img_shape, code_size=512)
encoder.load_weights("encoder.h5")
decoder.load_weights("decoder.h5")

# %%
for _ in range(5):
    image1,image2 = X_test[np.random.randint(0,len(X_test),size=2)]

    code1, code2 = encoder.predict(np.stack([image1,image2]))

    plt.figure(figsize=[10,4])
    for i,a in enumerate(np.linspace(0,1,num=7)):

        output_code = code1*(1-a) + code2*(a)
        output_image = decoder.predict(output_code[None])[0]

        plt.subplot(1,7,i+1)
        plt.imshow(output_image)
        plt.title("a=%.2f"%a)
        
    plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Of course there's a lot more you can do with autoencoders.
#
# If you want to generate images from scratch, however, we recommend you our honor track seminar about generative adversarial networks.
